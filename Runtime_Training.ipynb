# %%
print("hello world")

# %%
# !python main.py --cipher present80 --rounds 10 --pairs 2 --difference 0x0000000000000080 --delta-key-bit 56

# %%
print("Finding key bit with modified parameters...")
