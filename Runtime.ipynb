# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Finding input_diff
# !python finding_input_new.py --cipher simmeck3264 --scenario single-key --rounds 8 --out "differences_results/" --verbose

# %%
# Finding key_bit
# !python finding_input_new.py --cipher simmeck3264 --scenario related-key --rounds 15 --sweep-dk --sweep-samples 10000 --difference 0x20

# %%
# Single-key
# !python visualize_dataset.py --cipher simmeck3264 --scenario single-key --rounds 7 --pairs 8 --difference 0x20 --samples 50000 --plot
# Out:
# 2025-11-28 07:31:51.088920: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764315111.110904   20994 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764315111.117707   20994 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764315111.135111   20994 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Related-key
# !python visualize_dataset.py --cipher simmeck3264 --scenario related-key --rounds 7 --pairs 8 --difference 0x40 --key-bit 57 --samples 50000 --plot --elbow-kmax 8
# Out:
# 2025-11-28 07:42:47.105903: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764315767.126822   23771 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764315767.133071   23771 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1764315767.149485   23771 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python /content/drive/MyDrive/NDC/Related-key-mcp-attention-Inception-based-ND/visualize_dataset.py \
    --cipher present80 \
    --rounds 8 \
    --pairs 1 \
    --difference 0xa00000000000000000000000000000000 \
    --key-bit 79 \
    --samples 50000 \
    --plot \
    --out /content/drive/MyDrive/NDC/Related-key-mcp-attention-Inception-based-ND/analysis_results \
    --add-timestamp \
    --save-sweep
